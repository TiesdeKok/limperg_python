# %% [markdown]
# # Demonstration - Day 3

# %% [markdown]
# ## Imports

# %%
import os, sys, re
import pandas as pd
import numpy as np

import requests
from requests_html import HTMLSession

# %% [markdown]
# # API example

# %% [markdown]
# ## CoinGecko API
#
# https://www.coingecko.com/en/api/documentation

# %% [markdown]
# ## Let's test to make sure the API works

# %% [markdown]
# ## Find the coin ID for dogecoin

# %% [markdown]
# ## Get the price of dogecoin on May 5th 2021

# %% [markdown]
# ### Make it easier to modify

# %% [markdown]
# ## Put it into a function
#
# --> If time permits

# %% [markdown]
# # Web scraping example
#
# https://www.importgenius.com/search/APPLE

# %% [markdown]
# ## Retrieve the website

# %% [markdown]
# ## Get the first volume number
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Get the volume, name, and date for each of the items on the first page
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Bad approach

# %% [markdown]
# ### Good but fragile approach

# %% [markdown]
# ### Best and robust approach
#
# Step 1. get the blocks
# Step 2. get the info out of each block

# %% [markdown]
# ## How do we get the link to the company name?

# %% [markdown]
# ## How do we get all the pages?
#
# --> only if time permits
