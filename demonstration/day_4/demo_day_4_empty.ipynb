# %% [markdown]
# # Demonstration - Day 4

# %% [markdown]
# ## Imports

# %%
import os, sys, re
from pathlib import Path

# %%
import lxml.html
import unidecode
import html

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Spacy package import:

# %%
import en_core_web_lg
nlp = en_core_web_lg.load()

# %% [markdown]
# # objective
#
# Let's extract the text from Item 7.01 from a random sample of 8-K filings:
#
# ```python
# link_list = [
#     'https://www.sec.gov/Archives/edgar/data/1839341/000119312522167998/d318802d8k.htm',
#     'https://www.sec.gov/Archives/edgar/data/1623715/000095017022009510/imgo-20220512.htm',
#     'https://www.sec.gov/Archives/edgar/data/1692115/000169211522000011/swx-20220513.htm',
#     'https://www.sec.gov/Archives/edgar/data/1318641/000143774922013805/cbli20220527_8k.htm',
#     'https://www.sec.gov/Archives/edgar/data/1314772/000110465922035115/tm229421d4_8k.htm',
#     'https://www.sec.gov/Archives/edgar/data/318833/000119312522096199/d285947d8k.htm',
#     'https://www.sec.gov/Archives/edgar/data/0001810806/000119312521324500/d226908d8k.htm',
#     'https://www.sec.gov/Archives/edgar/data/1819516/000110465922027632/tm227836d1_8k.htm',
# ]
# ```
#
# ![image.png](attachment:image.png)

# %%
print('https://www.sec.gov/Archives/edgar/data/1839341/000119312522167998/d318802d8k.htm')
# Out:
# https://www.sec.gov/Archives/edgar/data/1839341/000119312522167998/d318802d8k.htm

# %% [markdown]
# ## Index html files

# %% [markdown]
# ## Load HTML files

# %% [markdown]
# ## Clean the text for a single document

# %% [markdown]
# ### Get rid of all the HTML
#
# Note, might have to add `raw_str.encode()` to get rid of encoding warning

# %% [markdown]
# ### Get rid of unicode characters
#
# ![image.png](attachment:image.png)
#
# https://www.compart.com/en/unicode/U+00A0

# %% [markdown]
# ### Remove all those extra newlines to make it easier to work with

# %% [markdown]
# ### Remove extra spaces

# %% [markdown]
# ## Apply cleaning steps to all filings

# %% [markdown]
# # Extract section

# %% [markdown]
# ## Test on a single item

# %% [markdown]
# ## Run for all

# %% [markdown]
# Why does one of them not work?

# %% [markdown]
# # Get some insights out of the data
#
# Let's say we need to convert it to the sentence level, steps:
#
# 1. Clean the text and get rid of newlines
# 2. Split the text into sentences
