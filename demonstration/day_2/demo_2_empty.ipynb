# %% [markdown]
# # Demonstration - Day 2

# %% [markdown]
# ## Dataset
#
# URLs:
# https://aqs.epa.gov/aqsweb/airdata/download_files.html
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline

# %%
import os, sys, copy
import pandas as pd
import numpy as np
from pathlib import Path

import matplotlib.pyplot as plt ## For graphs

# %% [markdown]
# ## Load the data

# %% [markdown]
# ### An aside on data paths
#
# relative paths vs. absolute paths
#
# raw strings vs. os.path.join vs. Pathlib

# %% [markdown]
# ### Load CSV file

# %% [markdown]
# -----
# # Inspect our dataset

# %% [markdown]
# ## How do we see what is in our dataset?
#
# `.info()`, `.head()`, `.tail()`, `.sample()`, `.iloc[999]`

# %% [markdown]
# ## Check datatypes

# %% [markdown]
# ## How many counties do we have?

# %% [markdown]
# ### How many observations per county?

# %% [markdown]
# ## Top 10 worst air quality observations in 2021?

# %% [markdown]
# ## Select all observations with an `aqi` above 225

# %% [markdown]
# ## Select all obervations in King county with a category that is not "Good"

# %% [markdown]
# -----
# # Modify our dataset

# %% [markdown]
# ## Create columns - basic
#
# Let's say we want to divide the `aqi` column by 10, three methods:

# %% [markdown]
# ### Method 1: Pandas series magic

# %% [markdown]
# ### Method 2: using apply with lambda

# %% [markdown]
# ### Method 3: using apply with a function

# %% [markdown]
# ## Create columns - advanced
#
# What if we need information from multiple columns?
#
# For example, we want to multiply AQI by the length of the county name?

# %% [markdown]
# ## Create columns - dates
#
# What if we want to add a month column to our dataset?

# %% [markdown]
# ## Transform dataset - Groupby

# %% [markdown]
# ### Which county had the worst average AQI in 2021?

# %% [markdown]
# ## Merge dataset

# %% [markdown]
# ### Load datasets

# %%
aqi_2020_df = pd.read_csv(data_folder / 'aqi_2020_wa.csv')
weather_2021_df = pd.read_csv(data_folder / 'weather_2021_wa.csv')

# %% [markdown]
# ### Stack two datasets on top of each other (i.e. 2021 + 2020)

# %% [markdown]
# ### Merge

# %% [markdown]
# # Create plots

# %% [markdown]
# ## Bar chart - average aqi by month

# %% [markdown]
# ## Show average aqi by day - line chart
